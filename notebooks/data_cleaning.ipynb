# %% [markdown]
# # import the data

# %%
import pandas as pd
import numpy as np



url="../data/product_info.csv"
df=pd.read_csv(url)

url_2="../data/final_reviews.csv"
df_review=pd.read_csv(url_2)
# Out:
# C:\Users\skrai\AppData\Local\Temp\ipykernel_25308\3755576595.py:10: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_review=pd.read_csv(url_2)

# %%
import pandas as pd

# Assuming you have the product data and review data as pandas DataFrames
# product_data = pd.DataFrame(...)
# review_data = pd.DataFrame(...)

# Merge the product data with the review data on 'product_id'
merged_data = pd.merge(df_review, df[['product_id', 'primary_category']], on='product_id', how='inner')

# Group by primary category and count the number of reviews
reviews_per_category = merged_data.groupby('primary_category').size().reset_index(name='nb_of_reviews')

# Display the result
print(reviews_per_category)
# Out:
#   primary_category  nb_of_reviews
# 0         Skincare        1092406

# %% [markdown]
# # Some EDA

# %%
df.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320  \
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type
# 0  3.6364     11.0             NaN                                 NaN  \
# 1  4.1538     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 2  4.2500     16.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 3  4.4762     21.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 4  3.2308     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
#
#   variation_value  ... online_only out_of_stock  sephora_exclusive
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8494 entries, 0 to 8493
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          8494 non-null   object
#  1   product_name        8494 non-null   object
#  2   brand_id            8494 non-null   int64
#  3   brand_name          8494 non-null   object
#  4   loves_count         8494 non-null   int64
#  5   rating              8216 non-null   float64
#  6   reviews             8216 non-null   float64
#  7   size                6863 non-null   object
#  8   variation_type      7050 non-null   object
#  9   variation_value     6896 non-null   object
#  10  variation_desc      1250 non-null   object
#  11  ingredients         7549 non-null   object
#  12  price_usd           8494 non-null   float64
#  13  value_price_usd     451 non-null    float64
#  14  sale_price_usd      270 non-null    float64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named df
# Group by 'primary_category' and count the number of products
category_counts = df['primary_category'].value_counts()

# Plot the data using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="viridis")
plt.title('Number of Products per Primary Category')
plt.xlabel('Primary Category')
plt.ylabel('Number of Products')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\skrai\AppData\Local\Temp\ipykernel_25308\2538051955.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette="viridis")

# %% [markdown]
# # Breakdown of Secondary Categories for Each Primary Category

# %%
# Drop rows where 'secondary_category' is NaN
df_filtered = df.dropna(subset=['secondary_category'])

# Group by 'primary_category' and 'secondary_category' and count the number of products
category_counts = df_filtered.groupby(['primary_category', 'secondary_category']).size().reset_index(name='count')

# Get a list of unique primary categories
primary_categories = category_counts['primary_category'].unique()

# Define the number of rows and columns for the grid layout
num_rows = len(primary_categories)
num_cols = 1  # One column for each primary category

# Increase the figure size
plt.figure(figsize=(15, 5 * num_rows))

for i, primary_category in enumerate(primary_categories, 1):
    plt.subplot(num_rows, num_cols, i)
    # Filter data for the current primary category
    data = category_counts[category_counts['primary_category'] == primary_category]
    sns.barplot(x='secondary_category', y='count', data=data, palette='viridis')
    plt.title(f'Number of Products per Secondary Category in {primary_category}')
    plt.xlabel('Secondary Category')
    plt.ylabel('Number of Products')
    plt.xticks(rotation=45, ha='right')

# Adjust layout to prevent overlapping
plt.tight_layout()
plt.show()
# Out:
# C:\Users\skrai\AppData\Local\Temp\ipykernel_25308\4135860148.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='secondary_category', y='count', data=data, palette='viridis')
# C:\Users\skrai\AppData\Local\Temp\ipykernel_25308\4135860148.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='secondary_category', y='count', data=data, palette='viridis')
# C:\Users\skrai\AppData\Local\Temp\ipykernel_25308\4135860148.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# check for nulll values

# %%
# Calculate the number of null values per column
null_counts = df.isnull().sum()

# Print the number of null values per column
print(null_counts)
# Out:
# product_id               0
# product_name             0
# brand_id                 0
# brand_name               0
# loves_count              0
# rating                 278
# reviews                278
# size                  1631
# variation_type        1444
# variation_value       1598
# variation_desc        7244
# ingredients            945
# price_usd                0
# value_price_usd       8043
# sale_price_usd        8224
# limited_edition          0
# new                      0
# online_only              0
# out_of_stock             0
# sephora_exclusive        0
# highlights            2207
# primary_category         0
# secondary_category       8
# tertiary_category      990
# child_count              0
# child_max_price       5740
# child_min_price       5740
# dtype: int64

# %% [markdown]
# # remove the empty reviews rows

# %%
df = df.dropna(subset=['reviews'])

# %% [markdown]
# # remove useless columns

# %%
columns_to_drop = ['online_only',"variation_type" ,"variation_value" ,"variation_desc" ,  'out_of_stock', 'sephora_exclusive', 'child_count', 'child_max_price', 'child_min_price']
df = df.drop(columns=columns_to_drop)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8216 entries, 0 to 8491
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          8216 non-null   object
#  1   product_name        8216 non-null   object
#  2   brand_id            8216 non-null   int64
#  3   brand_name          8216 non-null   object
#  4   loves_count         8216 non-null   int64
#  5   rating              8216 non-null   float64
#  6   reviews             8216 non-null   float64
#  7   size                6695 non-null   object
#  8   ingredients         7322 non-null   object
#  9   price_usd           8216 non-null   float64
#  10  value_price_usd     382 non-null    float64
#  11  sale_price_usd      263 non-null    float64
#  12  limited_edition     8216 non-null   int64
#  13  new                 8216 non-null   int64
#  14  highlights          6054 non-null   object
# ...

# %%
num_unique_values = df["primary_category"].unique()

print(num_unique_values)
# Out:
# ['Fragrance' 'Bath & Body' 'Mini Size' 'Hair' 'Makeup' 'Skincare'
#  'Tools & Brushes' 'Men' 'Gifts']

# %%
# Values to remove
values_to_remove = ["Bath & Body","Mini Size", 'Tools & Brushes', 'Men', 'Gifts']

# Filter out rows where 'primary_category' is in the values_to_remove list
df = df[['primary_category']== 'Skincare']

# %%
import ast

# Sample skin types

skin_types = ['dry', 'combo', 'normal', 'oily']

# Function to check if a skin type is in the highlights
def check_skin_type(highlights, skin_type):
    if pd.isna(highlights):  # Handle NaN values
        return 0
    try:
        highlights_list = ast.literal_eval(highlights.lower())  # Convert string representation of list to an actual list and lowercase it
        for item in highlights_list:
            if skin_type in item:
                return 1
    except (ValueError, SyntaxError):  # Catch errors if highlights is not a valid list string
        return 0
    return 0

# %%
# Function to check if "Vegan" is in the highlights
def check_vegan(highlights):
    if pd.isna(highlights):  # Handle NaN values
        return 0
    try:
        highlights_list = ast.literal_eval(highlights.lower())  # Convert string representation of list to an actual list and lowercase it
        if 'vegan' in highlights_list:
            return 1
    except (ValueError, SyntaxError):  # Catch errors if highlights is not a valid list string
        return 0
    return 0

# %%
# Create a new column for each skin type and populate it
for skin_type in skin_types:
    column_name = skin_type
    df[column_name] = df["highlights"].apply(lambda x: check_skin_type(x, skin_type))

# Add the Vegan column
df['vegan'] = df['highlights'].apply(check_vegan)

# %%
df.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320  \
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size
# 0  3.6364     11.0             NaN  \
# 1  4.1538     13.0  3.4 oz/ 100 mL
# 2  4.2500     16.0  3.4 oz/ 100 mL
# 3  4.4762     21.0  3.4 oz/ 100 mL
# 4  3.2308     13.0  3.4 oz/ 100 mL
#
#                                          ingredients  price_usd  ...  new
# 0  ['Capri Eau de Parfum:', 'Alcohol Denat. (SD A...       35.0  ...    0  \
# 1  ['Alcohol Denat. (SD Alcohol 39C), Parfum (Fra...      195.0  ...    0
# 2  ['Alcohol Denat. (SD Alcohol 39C), Parfum (Fra...      195.0  ...    0
# ...

# %%
df.rename(columns={'combo': 'combination'}, inplace=True)

# %%
df.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320  \
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size
# 0  3.6364     11.0             NaN  \
# 1  4.1538     13.0  3.4 oz/ 100 mL
# 2  4.2500     16.0  3.4 oz/ 100 mL
# 3  4.4762     21.0  3.4 oz/ 100 mL
# 4  3.2308     13.0  3.4 oz/ 100 mL
#
#                                          ingredients  price_usd  ...  new
# 0  ['Capri Eau de Parfum:', 'Alcohol Denat. (SD A...       35.0  ...    0  \
# 1  ['Alcohol Denat. (SD Alcohol 39C), Parfum (Fra...      195.0  ...    0
# 2  ['Alcohol Denat. (SD Alcohol 39C), Parfum (Fra...      195.0  ...    0
# ...

# %%
df["ingredients"]
# Out:
# 0       ['Capri Eau de Parfum:', 'Alcohol Denat. (SD A...
# 1       ['Alcohol Denat. (SD Alcohol 39C), Parfum (Fra...
# 2       ['Alcohol Denat. (SD Alcohol 39C), Parfum (Fra...
# 3       ['Alcohol Denat. (SD Alcohol 39C), Parfum (Fra...
# 4       ['Alcohol Denat. (SD Alcohol 39C), Parfum (Fra...
#                               ...
# 8487    ['The Slim Velvet Radical:', 'Dimethicone, Bis...
# 8488    ['Libre Eau de Parfum:', 'Alcohol, Parfum/Frag...
# 8489    ['Talc, Synthetic Fluorphlogopite, Triethylhex...
# 8490    ['Alcohol, Aqua / Water / Eau, Parfum / Fragra...
# 8491    ['Mon Paris Eau de Parfum:', 'Alcohol, Parfum/...
# Name: ingredients, Length: 7434, dtype: object

# %%
df = df[df['product_id'] != "P502216"]

# %%
df[df["price_usd"]>1000]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, brand_id, brand_name, loves_count, rating, reviews, size, ingredients, price_usd, value_price_usd, sale_price_usd, limited_edition, new, highlights, primary_category, secondary_category, tertiary_category, dry, combination, normal, oily, vegan]
# Index: []
#
# [0 rows x 23 columns]

# %%
#df.to_csv('../data/clean_products.csv', index=False)
